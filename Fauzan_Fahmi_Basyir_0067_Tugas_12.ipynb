# %% [markdown]
# <a href="https://colab.research.google.com/github/ZanZan76/Praktikum-Alpro/blob/main/Fauzan_Fahmi_Basyir_0067_Tugas_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Membuat program dengan input dan fungsi untuk menghitung

# %%
# a. Luas Persegi Panjang
def luas(panjang, lebar):
  return panjang * lebar

a = luas(8, 4)
print(a)
# Out:
# 32

# %%
# b. Volume Balok
def volume(panjang = 4, lebar = 6, tinggi = 8):
  hasil = panjang * lebar * tinggi
  return hasil

print(volume())
# Out:
# 192

# %%
import math

# c. Luas Lingkaran
def luas(r):
  return luas

r = 7
hasil = math.pi * r * r
print(hasil)
# Out:
# 153.93804002589985

# %%
import math

# d. Volume Bola
def volume(angka, r):
  return luas

angka = 4/3
r = 8
hasil = angka * math.pi * r * r * r
print(hasil)
# Out:
# 2144.660584850632
